# %%
with open('../data/0/pmn-m/link-elapsed-millis.txt') as f:
    times = f.read().splitlines()
times = [int(time) for time in times]
times.sort(reverse=True)
times
# Out:
# [10803,
#  10660,
#  10617,
#  10560,
#  10510,
#  10370,
#  10351,
#  10336,
#  10222,
#  10155,
#  10148,
#  10142,
#  10135,
#  10109,
#  10090,
#  10069,
#  10065,
#  10062,
#  10053,
#  10034,
#  10002,
#  9945,
#  9922,
#  9920,
#  9897,
#  9866,
#  9858,
#  9837,
#  9827,
#  9807,
#  9760,
#  9724,
#  9704,
#  9694,
#  9677,
#  9664,
#  9657,
#  9650,
#  9637,
#  9563,
#  9538,
#  9507,
#  9484,
#  9444,
#  9413,
#  9401,
#  9101,
#  8848,
#  7835,
#  7776,
#  7694,
#  7691,
#  7559,
#  7558,
#  7532,
#  7520,
#  7517,
#  7482,
#  7480,
#  7452,
#  7444,
#  7430,
#  7421,
#  7412,
#  7393,
#  7386,
#  7313,
#  7262,
#  7261,
#  7251,
#  7238,
#  7237,
#  7215,
#  7193,
#  7156,
#  7143,
#  7136,
#  7122,
#  7122,
#  7094,
#  7090,
#  7084,
#  7077,
#  7060,
#  7049,
#  7030,
#  6971,
#  6969,
#  6963,
#  6958,
#  6953,
#  6934,
#  6907,
#  6894,
#  6876,
#  6859,
#  6768,
#  6748,
#  6739,
#  6707,
#  6681,
#  6662,
#  6658,
#  6528,
#  6524,
#  6519,
#  6498,
#  6481,
# ...
